# %% [markdown]
# # guassing the Game

# %%
import random
random.randint(1,100)
# Out:
# 66

# %%
import random

jackpot =random.randint(1,100)


while True :
   a=int(input("Enter the guess number:"))
   if a < jackpot:
    print("You gussed  lowernumber, try bigger")
   elif a>jackpot:
      print("You gusssed  higher number,try  lower")
   else:
     print("You  are absolutely corrent!")
     break
# Out:
# Enter the guess number: 67
# You gussed  lowernumber, try bigger
# Enter the guess number: 86
# You gussed  lowernumber, try bigger
# Enter the guess number: 90
# You gussed  lowernumber, try bigger
# Enter the guess number: 99
# You gusssed  higher number,try  lower
# Enter the guess number: 96
# You gusssed  higher number,try  lower
# Enter the guess number: 94
# You gusssed  higher number,try  lower
# Enter the guess number: 92
# You gusssed  higher number,try  lower
# Enter the guess number: 91
# You  are absolutely corrent!
